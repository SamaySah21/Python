# %%
a = 5
b = 6
print(a)
print(b)
# Out:
# 5
# 6

# %%
# using third variable .. third variable is taking space
temp = a
a = b
b = temp

print(a)
print(b)
# Out:
# 6
# 5

# %%
## 11 is 4 bit.. thus taking 1 extra bit
a = 5
b = 6

a = a+b # 11
b = a-b # 5
a = a-b # 6

print(a)
print(b)
# Out:
# 6
# 5
