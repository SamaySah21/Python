# %%
## Basic Function
def firstFunction():
    print("hello world")
firstFunctionFunction()
# Out:
# hello world

# %%
# if we dont give any content inside function body it will give error.
def firstFunction():

firstFunction()
# Out:
#   File "<ipython-input-6-7b2c25f1cdad>", line 4
#     firstFunction()
#                 ^
# IndentationError: expected an indented block

# %%
# to avoid above ,, or sometime we jus want to give function name and contentwe can put later than use "pass" .. 
## "pass" it will avoid error
def firstFunction():
    pass
firstFunction()

# %%
## args and kwargs
def fetchArguments(*args, **kwargs):
    print(args) ## return tuples of arguments
    print(kwargs) ## returns key value pair (dictionary form)
fetchArguments("samay","sah","samay", "is", subject1 = "Maths" , subject2 = "Python")
# Out:
# ('samay', 'sah', 'samay', 'is')
# {'subject1': 'Maths', 'subject2': 'Python'}
