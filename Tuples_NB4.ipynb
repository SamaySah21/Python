# %% [markdown]
# ### TUPLES
# #### Tuple is like list in terms of storing value.
# #### But tuple is immuatble( item assignment not possible).
# #### use list where we need to update values , and use tuple where we dont want to update values.
# #### As tuples are immutable , thus there are less methods available in tuples as compared to lists.

# %%
courses_tuple = ("history", "cviics", "art", "maths")
courses_tupleses_tuple
# Out:
# ('history', 'cviics', 'art', 'maths')

# %%
print(dir(courses_tuple))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'count', 'index']

# %% [markdown]
# ####  As above we can see , there are no functions like insert , extend available in tuples.

# %%
# tuples are immutable( item assignment does not support)
courses_tuple[0] = "change value"
courses_tuple
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-0ca1759c5479> in <module>
#       1 # tuples are immutable( item assignment does not support)
# ----> 2 courses_tuple[0] = "change value"
#       3 courses_tuple
#
# TypeError: 'tuple' object does not support item assignment

# %%
## We can overide the whole tuple but cannt replace the single values .
## Note : As tuple is immutable , it will reallocate to new address in memory for "my_tup". So, in tuple if we overide , 
## than new address creates.
courses_tuple = (5,6) 
courses_tuple
# Out:
# (5, 6)
