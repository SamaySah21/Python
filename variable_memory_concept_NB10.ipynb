# %%
a = 10
print(a)
print(id(a))
# Out:
# 10
# 140722141242032

# %%
b = 10
print(b)
print(id(b))
# Out:
# 10
# 140722141242032

# %%
c = a
print(c)
print(id(c))
# Out:
# 10
# 140722141242032

# %%
c = b
print(c)
print(id(c))
# Out:
# 10
# 140722141242032

# %% [markdown]
# #### From above it can be understood that in python actually assigned the space to 10. So, if we will make any no. of variable whose value is 10 , than all will have same address

# %% [markdown]
# #### When there is no variable which is pointing to 10 , thanby garbage collection mechanism 10 will destroy.
